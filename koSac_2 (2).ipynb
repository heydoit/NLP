# %%
pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.8/dist-packages (0.6.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (1.4.1)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from JPype1>=0.7.0->konlpy) (23.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

import re
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from konlpy.tag import Kkma, Komoran, Okt, Hannanum  #Mecab은 윈도우에서 작동 불가능

from konlpy import tag
from konlpy.corpus import kolaw
# from konlpy.utils import csvwrite, pprint

from nltk.tokenize import sent_tokenize

# %%
Lyrics = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/odatt/Lyrics_final.csv')

# %%
# 행복, 희망 => 1(긍정), 슬픔, 분노 => 0(부정) 으로 이진분류
def rating_to_label(label):
    if label == 0 or label == 3:
        return 1
    else:
        return 0

Lyrics['y'] = Lyrics['label'].apply(lambda x: rating_to_label(x))
Lyrics_pos = Lyrics[Lyrics['y'] == 1]
Lyrics_neg = Lyrics[Lyrics['y'] == 0]

# %%
kosac = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/odatt/polarity.csv")

# %% [markdown]
# ### 태깅

# %%
okt = Okt() 
kkma = Kkma() #kosac에 알맞는 데이터 값
komoran = Komoran()
hannanum = Hannanum()

# %% [markdown]
# kkma 이용

# %%
data_pos = Lyrics_pos['Lyrics'].to_string()
data_neg = Lyrics_neg['Lyrics'].to_string()

kkma_pos = kkma.pos(data_pos)
kkma_neg = kkma.pos(data_neg)


# 형태소 필터링 

# kkma_text = ['NNG', 'NNP', 'NNB','VV','VA','MAG','IC','NR']
# clean_words_pos = []
# for i in kkma_pos:
#   for j in kkma_text:
#     if j in i:
#       clean_words_pos.append(i)

# clean_words_neg = []
# for i in kkma_neg:
#   for j in kkma_text:
#     if j in i:
#       clean_words_neg.append(i)

# %%
# 단어+형태소 합치기 

kkma_pos_list = []
kkma_neg_list = []

for i in range(len(kkma_pos)):
  pos_text = kkma_pos[i][0]+'/'+kkma_pos[i][1]
  kkma_pos_list.append(pos_text)
  i += 1

for i in range(len(kkma_neg)):
  neg_text = kkma_neg[i][0]+'/'+kkma_neg[i][1]
  kkma_neg_list.append(neg_text)
  i += 1

# %%
# 형태소분석이 된 긍정가사를 가사별로 리스트화하여 dataframe으로 정리
text_pos = ''.join(str(i) for i in kkma_pos_list)
text_neg = ' '.join(str(i) for i in kkma_neg_list)

text_pos_list = []
numList_pos = []

for i in range(1000):
  if(text_pos.find(f'{i}') > -1):
    num_pos = text_pos.find(f'{i}')
    numList_pos.append(num_pos)

for i in range(len(numList_pos)):
  text = ""
  if(i == len(numList_pos)-1):
    text = text_pos[int(numList_pos[i]):len(text_pos)]
  else:
    text = text_pos[int(numList_pos[i]):int(numList_pos[i+1])]
  text_pos_list.append(text)

aa = text_pos_list[0]
text_pos_list.append(aa)

pos = pd.DataFrame(text_pos_list)
pos = pos.drop(0, axis = 0 )
pos.columns = ['word']

# 형태소분석이 된 부정가사를 가사별로 리스트화하여 dataframe으로 정리
text_neg_list = []
numList_neg = []

for i in range(196,1000):
  if(text_neg.find(f'{i}') > -1):
    num_neg = text_neg.find(f'{i}')
    numList_neg.append(num_neg)

for i in range(len(numList_neg)):
  text_1 = ""
  if(i == len(numList_neg)-1):
    text_1 = text_neg[numList_neg[i]:len(text_neg)]
  else:
    text_1 = text_neg[numList_neg[i]:int(numList_neg[i+1])]
  text_neg_list.append(text_1)


dd = text_neg_list[0]
text_neg_list.append(dd)

neg = pd.DataFrame(text_neg_list)
neg = neg.drop(0, axis = 0 )
neg.columns = ['word']

# %% [markdown]
# ####okt 이용

# %%
okt = Okt()

# %%
data_pos = Lyrics_pos['Lyrics'].to_string()
data_neg = Lyrics_neg['Lyrics'].to_string()

# %%
pos_pos = okt.pos(data_pos)
list_pos = []
list_neg = []
for i in range(len(pos_pos)):
  pos_text = pos_pos[i][0]+'/'+pos_pos[i][1]
  list_pos.append(pos_text)
  i += 1
  
pos_neg = okt.pos(data_neg)
for i in range(len(pos_neg)):
  neg_text = pos_neg[i][0]+'/'+pos_neg[i][1]
  list_neg.append(neg_text)
  i += 1

# %%
# 형태소분석이 된 긍정가사를 가사별로 리스트화하여 dataframe으로 정리
text = ' '.join(str(i) for i in kkma_pos)
text_pos = text.split('/Number')

pos = pd.DataFrame(text_pos)
pos = pos.drop(0, axis = 0 )
pos.columns = ['word']

# 형태소분석이 된 부정가사를 가사별로 리스트화하여 dataframe으로 정리
text = ' '.join(str(i) for i in kkma_neg)
text_neg = text.split('/Number')

neg = pd.DataFrame(text_neg)
neg = neg.drop(0, axis = 0 )
neg.columns = ['word']

# %% [markdown]
# ### KoSac 코드 (kkma 이용)

# %% [markdown]
# 가사별로 형태소분석 list로 나눠주기 => 이후 dataframe화 함

# %% [markdown]
# :

# %%
# kosac을 POS 와 NEG로 분류
kosac_pos = kosac[kosac['max.value'] == 'POS']
kosac_neg = kosac[kosac['max.value'] == 'NEG']

# %%
def LyricsWordCount(arrList, emotion):
    list = []
    i=1

    # 감성 점수 구하기
    for Lyrics in arrList:
        neg_count = 0       # 부정 점수
        pos_count = 0       # 긍정 점수
        num = 0             # 감성 점수
        
        # 긍정 점수 구하기
        for pos_text in kosac_pos['ngram']:
            pos_find = Lyrics.find(pos_text)
            if(pos_find > -1):
                pos_count += 1
            else: pos_count += 0


        # 부정 점수 구하기
        for neg_text in kosac_neg['ngram']:
            neg_find = Lyrics.find(neg_text)
            if(neg_find > -1):
                neg_count += 1
            else: pos_count += 0

        # 감성 점수 공식
        if emotion == '긍정':
            num = pos_count - neg_count
        elif emotion == '부정':
            num = neg_count - pos_count

        # 감성 점수 공식
        if emotion == '긍정':
          if pos_count == 0 or neg_count == 0:
            num = 0
          else:
            num = pos_count/(pos_count + neg_count)
            
        elif emotion == '부정':
          if pos_count == 0 or neg_count == 0:
            num = 0
          else:
            num = neg_count/(pos_count + neg_count)

        # 긍, 부정 결과
        if emotion == '긍정':
          if num >= 0.5:
            result = '긍정'
          elif num < 0.5:
            result = '부정'
        
        if emotion == '부정':
          if num >= 0.5:
            result = '부정'
          elif num < 0.5:
            result = '긍정'


        srt = f"{i}번 노래 결과 : 긍정 : {pos_count}, 부정 : {neg_count} , 감성 점수 : {round(num,3)}  {result}"
        i = i + 1

        list.append(srt)
    return list

pos_result = LyricsWordCount(pos['word'], "긍정")
neg_result = LyricsWordCount(neg['word'], "부정")

print('긍정 노래')
for pos in pos_result:
    print(pos)

print('부정 노래')
for neg in neg_result:
    print(neg)
# Out:
# 긍정 노래
# 1번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.4  부정
# 2번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 3번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 4번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.545  긍정
# 5번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.667  긍정
# 6번 노래 결과 : 긍정 : 7, 부정 : 11 , 감성 점수 : 0.389  부정
# 7번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 8번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.286  부정
# 9번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 10번 노래 결과 : 긍정 : 6, 부정 : 2 , 감성 점수 : 0.75  긍정
# 11번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.357  부정
# 12번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.286  부정
# 13번 노래 결과 : 긍정 : 5, 부정 : 4 , 감성 점수 : 0.556  긍정
# 14번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.385  부정
# 15번 노래 결과 : 긍정 : 10, 부정 : 3 , 감성 점수 : 0.769  긍정
# 16번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 17번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 18번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 19번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.429  부정
# 20번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 21번 노래 결과 : 긍정 : 1, 부정 : 4 , 감성 점수 : 0.2  부정
# 22번 노래 결과 : 긍정 : 6, 부정 : 11 , 감성 점수 : 0.353  부정
# 23번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.467  부정
# 24번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.667  긍정
# 25번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.6  긍정
# 26번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.471  부정
# 27번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.462  부정
# 28번 노래 결과 : 긍정 : 6, 부정 : 11 , 감성 점수 : 0.353  부정
# 29번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.385  부정
# 30번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 31번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.667  긍정
# 32번 노래 결과 : 긍정 : 5, 부정 : 2 , 감성 점수 : 0.714  긍정
# 33번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.364  부정
# 34번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 35번 노래 결과 : 긍정 : 12, 부정 : 5 , 감성 점수 : 0.706  긍정
# 36번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.529  긍정
# 37번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 38번 노래 결과 : 긍정 : 3, 부정 : 5 , 감성 점수 : 0.375  부정
# 39번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 40번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.467  부정
# 41번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 42번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.533  긍정
# 43번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.357  부정
# 44번 노래 결과 : 긍정 : 9, 부정 : 3 , 감성 점수 : 0.75  긍정
# 45번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 46번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 47번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.529  긍정
# 48번 노래 결과 : 긍정 : 4, 부정 : 6 , 감성 점수 : 0.4  부정
# 49번 노래 결과 : 긍정 : 3, 부정 : 5 , 감성 점수 : 0.375  부정
# 50번 노래 결과 : 긍정 : 7, 부정 : 3 , 감성 점수 : 0.7  긍정
# 51번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.375  부정
# 52번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.357  부정
# 53번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.545  긍정
# 54번 노래 결과 : 긍정 : 4, 부정 : 3 , 감성 점수 : 0.571  긍정
# 55번 노래 결과 : 긍정 : 5, 부정 : 11 , 감성 점수 : 0.312  부정
# 56번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.429  부정
# 57번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.545  긍정
# 58번 노래 결과 : 긍정 : 3, 부정 : 11 , 감성 점수 : 0.214  부정
# 59번 노래 결과 : 긍정 : 10, 부정 : 4 , 감성 점수 : 0.714  긍정
# 60번 노래 결과 : 긍정 : 3, 부정 : 12 , 감성 점수 : 0.2  부정
# 61번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 62번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.467  부정
# 63번 노래 결과 : 긍정 : 6, 부정 : 14 , 감성 점수 : 0.3  부정
# 64번 노래 결과 : 긍정 : 10, 부정 : 3 , 감성 점수 : 0.769  긍정
# 65번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 66번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.4  부정
# 67번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.429  부정
# 68번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.667  긍정
# 69번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.357  부정
# 70번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.6  긍정
# 71번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.375  부정
# 72번 노래 결과 : 긍정 : 8, 부정 : 12 , 감성 점수 : 0.4  부정
# 73번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.562  긍정
# 74번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.467  부정
# 75번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  긍정
# 76번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.471  부정
# 77번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 78번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.562  긍정
# 79번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.615  긍정
# 80번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.533  긍정
# 81번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.692  긍정
# 82번 노래 결과 : 긍정 : 6, 부정 : 3 , 감성 점수 : 0.667  긍정
# 83번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.615  긍정
# 84번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  긍정
# 85번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  긍정
# 86번 노래 결과 : 긍정 : 3, 부정 : 8 , 감성 점수 : 0.273  부정
# 87번 노래 결과 : 긍정 : 12, 부정 : 9 , 감성 점수 : 0.571  긍정
# 88번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.375  부정
# 89번 노래 결과 : 긍정 : 7, 부정 : 4 , 감성 점수 : 0.636  긍정
# 90번 노래 결과 : 긍정 : 4, 부정 : 9 , 감성 점수 : 0.308  부정
# 91번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.429  부정
# 92번 노래 결과 : 긍정 : 14, 부정 : 3 , 감성 점수 : 0.824  긍정
# 93번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 94번 노래 결과 : 긍정 : 7, 부정 : 13 , 감성 점수 : 0.35  부정
# 95번 노래 결과 : 긍정 : 3, 부정 : 10 , 감성 점수 : 0.231  부정
# 96번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.667  긍정
# 97번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  긍정
# 98번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.692  긍정
# 99번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.667  긍정
# 100번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.529  긍정
# 101번 노래 결과 : 긍정 : 11, 부정 : 4 , 감성 점수 : 0.733  긍정
# 102번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.588  긍정
# 103번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.529  긍정
# 104번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.562  긍정
# 105번 노래 결과 : 긍정 : 10, 부정 : 0 , 감성 점수 : 0  부정
# 106번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 107번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.615  긍정
# 108번 노래 결과 : 긍정 : 2, 부정 : 10 , 감성 점수 : 0.167  부정
# 109번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.588  긍정
# 110번 노래 결과 : 긍정 : 4, 부정 : 4 , 감성 점수 : 0.5  긍정
# 111번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 112번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 113번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.6  긍정
# 114번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 115번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.471  부정
# 116번 노래 결과 : 긍정 : 10, 부정 : 6 , 감성 점수 : 0.625  긍정
# 117번 노래 결과 : 긍정 : 9, 부정 : 10 , 감성 점수 : 0.474  부정
# 118번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.545  긍정
# 119번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 120번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 121번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 122번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 123번 노래 결과 : 긍정 : 8, 부정 : 10 , 감성 점수 : 0.444  부정
# 124번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  긍정
# 125번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.6  긍정
# 126번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 127번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 128번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 129번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.562  긍정
# 130번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.375  부정
# 131번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 132번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.429  부정
# 133번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  긍정
# 134번 노래 결과 : 긍정 : 10, 부정 : 3 , 감성 점수 : 0.769  긍정
# 135번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 136번 노래 결과 : 긍정 : 14, 부정 : 7 , 감성 점수 : 0.667  긍정
# 137번 노래 결과 : 긍정 : 5, 부정 : 10 , 감성 점수 : 0.333  부정
# 138번 노래 결과 : 긍정 : 10, 부정 : 10 , 감성 점수 : 0.5  긍정
# 139번 노래 결과 : 긍정 : 12, 부정 : 0 , 감성 점수 : 0  부정
# 140번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 141번 노래 결과 : 긍정 : 3, 부정 : 8 , 감성 점수 : 0.273  부정
# 142번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  긍정
# 143번 노래 결과 : 긍정 : 13, 부정 : 5 , 감성 점수 : 0.722  긍정
# 144번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 145번 노래 결과 : 긍정 : 4, 부정 : 5 , 감성 점수 : 0.444  부정
# 146번 노래 결과 : 긍정 : 9, 부정 : 5 , 감성 점수 : 0.643  긍정
# 147번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 148번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  긍정
# 149번 노래 결과 : 긍정 : 10, 부정 : 4 , 감성 점수 : 0.714  긍정
# 150번 노래 결과 : 긍정 : 2, 부정 : 8 , 감성 점수 : 0.2  부정
# 151번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 152번 노래 결과 : 긍정 : 4, 부정 : 3 , 감성 점수 : 0.571  긍정
# 153번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 154번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.588  긍정
# 155번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.667  긍정
# 156번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 157번 노래 결과 : 긍정 : 3, 부정 : 7 , 감성 점수 : 0.3  부정
# 158번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 159번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  긍정
# 160번 노래 결과 : 긍정 : 10, 부정 : 2 , 감성 점수 : 0.833  긍정
# 161번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 162번 노래 결과 : 긍정 : 8, 부정 : 3 , 감성 점수 : 0.727  긍정
# 163번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 164번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  긍정
# 165번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 166번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.462  부정
# 167번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  긍정
# 168번 노래 결과 : 긍정 : 9, 부정 : 9 , 감성 점수 : 0.5  긍정
# 169번 노래 결과 : 긍정 : 8, 부정 : 11 , 감성 점수 : 0.421  부정
# 170번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.385  부정
# 171번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 172번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.667  긍정
# 173번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  긍정
# 174번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.588  긍정
# 175번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.429  부정
# 176번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.471  부정
# 177번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 178번 노래 결과 : 긍정 : 7, 부정 : 11 , 감성 점수 : 0.389  부정
# 179번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.562  긍정
# 180번 노래 결과 : 긍정 : 9, 부정 : 5 , 감성 점수 : 0.643  긍정
# 181번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.429  부정
# 182번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.286  부정
# 183번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 184번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.533  긍정
# 185번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.375  부정
# 186번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.529  긍정
# 187번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.615  긍정
# 188번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.588  긍정
# 189번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 190번 노래 결과 : 긍정 : 5, 부정 : 11 , 감성 점수 : 0.312  부정
# 191번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 192번 노래 결과 : 긍정 : 7, 부정 : 4 , 감성 점수 : 0.636  긍정
# 193번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.429  부정
# 194번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.467  부정
# 195번 노래 결과 : 긍정 : 9, 부정 : 5 , 감성 점수 : 0.643  긍정
# 196번 노래 결과 : 긍정 : 7, 부정 : 3 , 감성 점수 : 0.7  긍정
# 197번 노래 결과 : 긍정 : 5, 부정 : 10 , 감성 점수 : 0.333  부정
# 198번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 199번 노래 결과 : 긍정 : 1, 부정 : 4 , 감성 점수 : 0.2  부정
# 200번 노래 결과 : 긍정 : 9, 부정 : 9 , 감성 점수 : 0.5  긍정
# 201번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 202번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 203번 노래 결과 : 긍정 : 7, 부정 : 1 , 감성 점수 : 0.875  긍정
# 204번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.615  긍정
# 205번 노래 결과 : 긍정 : 4, 부정 : 1 , 감성 점수 : 0.8  긍정
# 206번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.667  긍정
# 207번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.412  부정
# 208번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  긍정
# 209번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.385  부정
# 210번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  긍정
# 211번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 212번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.529  긍정
# 213번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.545  긍정
# 214번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 215번 노래 결과 : 긍정 : 5, 부정 : 4 , 감성 점수 : 0.556  긍정
# 216번 노래 결과 : 긍정 : 1, 부정 : 4 , 감성 점수 : 0.2  부정
# 217번 노래 결과 : 긍정 : 3, 부정 : 7 , 감성 점수 : 0.3  부정
# 218번 노래 결과 : 긍정 : 4, 부정 : 6 , 감성 점수 : 0.4  부정
# 219번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.615  긍정
# 220번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 221번 노래 결과 : 긍정 : 8, 부정 : 10 , 감성 점수 : 0.444  부정
# 222번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 223번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.462  부정
# 224번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  긍정
# 225번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.412  부정
# 226번 노래 결과 : 긍정 : 9, 부정 : 9 , 감성 점수 : 0.5  긍정
# 227번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.286  부정
# 228번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.615  긍정
# 229번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.545  긍정
# 230번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 231번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.4  부정
# 232번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 233번 노래 결과 : 긍정 : 4, 부정 : 11 , 감성 점수 : 0.267  부정
# 234번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 235번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 236번 노래 결과 : 긍정 : 3, 부정 : 10 , 감성 점수 : 0.231  부정
# 237번 노래 결과 : 긍정 : 5, 부정 : 10 , 감성 점수 : 0.333  부정
# 238번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 239번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 240번 노래 결과 : 긍정 : 6, 부정 : 15 , 감성 점수 : 0.286  부정
# 241번 노래 결과 : 긍정 : 10, 부정 : 2 , 감성 점수 : 0.833  긍정
# 242번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.364  부정
# 243번 노래 결과 : 긍정 : 10, 부정 : 6 , 감성 점수 : 0.625  긍정
# 244번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 245번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.471  부정
# 246번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 247번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 248번 노래 결과 : 긍정 : 10, 부정 : 10 , 감성 점수 : 0.5  긍정
# 249번 노래 결과 : 긍정 : 4, 부정 : 8 , 감성 점수 : 0.333  부정
# 250번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.412  부정
# 251번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 252번 노래 결과 : 긍정 : 4, 부정 : 8 , 감성 점수 : 0.333  부정
# 253번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.588  긍정
# 254번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.533  긍정
# 255번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 256번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  긍정
# 257번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.583  긍정
# 258번 노래 결과 : 긍정 : 10, 부정 : 4 , 감성 점수 : 0.714  긍정
# 259번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.615  긍정
# 260번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.533  긍정
# 261번 노래 결과 : 긍정 : 10, 부정 : 8 , 감성 점수 : 0.556  긍정
# 262번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 263번 노래 결과 : 긍정 : 5, 부정 : 12 , 감성 점수 : 0.294  부정
# 264번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 265번 노래 결과 : 긍정 : 12, 부정 : 8 , 감성 점수 : 0.6  긍정
# 266번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 267번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.4  부정
# 268번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.667  긍정
# 269번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 270번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.364  부정
# 271번 노래 결과 : 긍정 : 9, 부정 : 3 , 감성 점수 : 0.75  긍정
# 272번 노래 결과 : 긍정 : 7, 부정 : 11 , 감성 점수 : 0.389  부정
# 273번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.467  부정
# 274번 노래 결과 : 긍정 : 6, 부정 : 13 , 감성 점수 : 0.316  부정
# 275번 노래 결과 : 긍정 : 11, 부정 : 3 , 감성 점수 : 0.786  긍정
# 276번 노래 결과 : 긍정 : 8, 부정 : 10 , 감성 점수 : 0.444  부정
# 277번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.462  부정
# 278번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.538  긍정
# 279번 노래 결과 : 긍정 : 9, 부정 : 5 , 감성 점수 : 0.643  긍정
# 280번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 281번 노래 결과 : 긍정 : 13, 부정 : 10 , 감성 점수 : 0.565  긍정
# 282번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.462  부정
# 283번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 284번 노래 결과 : 긍정 : 9, 부정 : 5 , 감성 점수 : 0.643  긍정
# 285번 노래 결과 : 긍정 : 9, 부정 : 9 , 감성 점수 : 0.5  긍정
# 286번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.286  부정
# 287번 노래 결과 : 긍정 : 4, 부정 : 9 , 감성 점수 : 0.308  부정
# 288번 노래 결과 : 긍정 : 8, 부정 : 3 , 감성 점수 : 0.727  긍정
# 289번 노래 결과 : 긍정 : 4, 부정 : 9 , 감성 점수 : 0.308  부정
# 290번 노래 결과 : 긍정 : 9, 부정 : 9 , 감성 점수 : 0.5  긍정
# 291번 노래 결과 : 긍정 : 3, 부정 : 7 , 감성 점수 : 0.3  부정
# 292번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.667  긍정
# 293번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.4  부정
# 294번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.533  긍정
# 295번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.385  부정
# 296번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 297번 노래 결과 : 긍정 : 9, 부정 : 10 , 감성 점수 : 0.474  부정
# 298번 노래 결과 : 긍정 : 5, 부정 : 12 , 감성 점수 : 0.294  부정
# 299번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.462  부정
# 300번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.545  긍정
# 301번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.529  긍정
# 302번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.692  긍정
# 303번 노래 결과 : 긍정 : 4, 부정 : 9 , 감성 점수 : 0.308  부정
# 304번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.533  긍정
# 305번 노래 결과 : 긍정 : 5, 부정 : 3 , 감성 점수 : 0.625  긍정
# 306번 노래 결과 : 긍정 : 3, 부정 : 6 , 감성 점수 : 0.333  부정
# 307번 노래 결과 : 긍정 : 9, 부정 : 9 , 감성 점수 : 0.5  긍정
# 308번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.529  긍정
# 309번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.357  부정
# 310번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.438  부정
# 311번 노래 결과 : 긍정 : 4, 부정 : 6 , 감성 점수 : 0.4  부정
# 312번 노래 결과 : 긍정 : 3, 부정 : 4 , 감성 점수 : 0.429  부정
# 313번 노래 결과 : 긍정 : 3, 부정 : 9 , 감성 점수 : 0.25  부정
# 314번 노래 결과 : 긍정 : 7, 부정 : 12 , 감성 점수 : 0.368  부정
# 315번 노래 결과 : 긍정 : 3, 부정 : 1 , 감성 점수 : 0.75  긍정
# 316번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.417  부정
# 317번 노래 결과 : 긍정 : 4, 부정 : 9 , 감성 점수 : 0.308  부정
# 318번 노래 결과 : 긍정 : 7, 부정 : 15 , 감성 점수 : 0.318  부정
# 319번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 320번 노래 결과 : 긍정 : 4, 부정 : 8 , 감성 점수 : 0.333  부정
# 321번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 322번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.692  긍정
# 323번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.6  긍정
# 324번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  긍정
# 325번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.467  부정
# 326번 노래 결과 : 긍정 : 9, 부정 : 5 , 감성 점수 : 0.643  긍정
# 327번 노래 결과 : 긍정 : 4, 부정 : 6 , 감성 점수 : 0.4  부정
# 328번 노래 결과 : 긍정 : 1, 부정 : 3 , 감성 점수 : 0.25  부정
# 329번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.286  부정
# 330번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.588  긍정
# 331번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.467  부정
# 332번 노래 결과 : 긍정 : 3, 부정 : 5 , 감성 점수 : 0.375  부정
# 333번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.571  긍정
# 334번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.692  긍정
# 335번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.455  부정
# 336번 노래 결과 : 긍정 : 4, 부정 : 5 , 감성 점수 : 0.444  부정
# 337번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.462  부정
# 338번 노래 결과 : 긍정 : 4, 부정 : 6 , 감성 점수 : 0.4  부정
# 339번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.375  부정
# 340번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.6  긍정
# 341번 노래 결과 : 긍정 : 12, 부정 : 9 , 감성 점수 : 0.571  긍정
# 342번 노래 결과 : 긍정 : 9, 부정 : 5 , 감성 점수 : 0.643  긍정
# 343번 노래 결과 : 긍정 : 3, 부정 : 9 , 감성 점수 : 0.25  부정
# 344번 노래 결과 : 긍정 : 2, 부정 : 6 , 감성 점수 : 0.25  부정
# 345번 노래 결과 : 긍정 : 11, 부정 : 7 , 감성 점수 : 0.611  긍정
# 346번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  긍정
# 부정 노래
# 1번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.588  부정
# 2번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 3번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 4번 노래 결과 : 긍정 : 4, 부정 : 3 , 감성 점수 : 0.429  긍정
# 5번 노래 결과 : 긍정 : 5, 부정 : 11 , 감성 점수 : 0.688  부정
# 6번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 7번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.455  긍정
# 8번 노래 결과 : 긍정 : 3, 부정 : 11 , 감성 점수 : 0.786  부정
# 9번 노래 결과 : 긍정 : 10, 부정 : 4 , 감성 점수 : 0.286  긍정
# 10번 노래 결과 : 긍정 : 3, 부정 : 12 , 감성 점수 : 0.8  부정
# 11번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 12번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 13번 노래 결과 : 긍정 : 6, 부정 : 13 , 감성 점수 : 0.684  부정
# 14번 노래 결과 : 긍정 : 10, 부정 : 3 , 감성 점수 : 0.231  긍정
# 15번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 16번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 17번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 18번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.333  긍정
# 19번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 20번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.4  긍정
# 21번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.625  부정
# 22번 노래 결과 : 긍정 : 8, 부정 : 12 , 감성 점수 : 0.6  부정
# 23번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.438  긍정
# 24번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 25번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  부정
# 26번 노래 결과 : 긍정 : 10, 부정 : 8 , 감성 점수 : 0.444  긍정
# 27번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 28번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.438  긍정
# 29번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.385  긍정
# 30번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.467  긍정
# 31번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.308  긍정
# 32번 노래 결과 : 긍정 : 6, 부정 : 3 , 감성 점수 : 0.333  긍정
# 33번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.385  긍정
# 34번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  부정
# 35번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  부정
# 36번 노래 결과 : 긍정 : 3, 부정 : 8 , 감성 점수 : 0.727  부정
# 37번 노래 결과 : 긍정 : 12, 부정 : 9 , 감성 점수 : 0.429  긍정
# 38번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.625  부정
# 39번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 40번 노래 결과 : 긍정 : 4, 부정 : 9 , 감성 점수 : 0.692  부정
# 41번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 42번 노래 결과 : 긍정 : 14, 부정 : 3 , 감성 점수 : 0.176  긍정
# 43번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 44번 노래 결과 : 긍정 : 6, 부정 : 11 , 감성 점수 : 0.647  부정
# 45번 노래 결과 : 긍정 : 3, 부정 : 10 , 감성 점수 : 0.769  부정
# 46번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.333  긍정
# 47번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  부정
# 48번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.308  긍정
# 49번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.333  긍정
# 50번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 51번 노래 결과 : 긍정 : 11, 부정 : 4 , 감성 점수 : 0.267  긍정
# 52번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.412  긍정
# 53번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 54번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.438  긍정
# 55번 노래 결과 : 긍정 : 9, 부정 : 1 , 감성 점수 : 0.1  긍정
# 56번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 57번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 58번 노래 결과 : 긍정 : 4, 부정 : 8 , 감성 점수 : 0.667  부정
# 59번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.412  긍정
# 60번 노래 결과 : 긍정 : 4, 부정 : 4 , 감성 점수 : 0.5  부정
# 61번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 62번 노래 결과 : 긍정 : 14, 부정 : 7 , 감성 점수 : 0.333  긍정
# 63번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.4  긍정
# 64번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 65번 노래 결과 : 긍정 : 10, 부정 : 6 , 감성 점수 : 0.375  긍정
# 66번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.625  부정
# 67번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.455  긍정
# 68번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 69번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 70번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 71번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.545  부정
# 72번 노래 결과 : 긍정 : 8, 부정 : 10 , 감성 점수 : 0.556  부정
# 73번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  부정
# 74번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.4  긍정
# 75번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 76번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 77번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 78번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.625  부정
# 79번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 80번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 81번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  부정
# 82번 노래 결과 : 긍정 : 10, 부정 : 3 , 감성 점수 : 0.231  긍정
# 83번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 84번 노래 결과 : 긍정 : 14, 부정 : 7 , 감성 점수 : 0.333  긍정
# 85번 노래 결과 : 긍정 : 5, 부정 : 10 , 감성 점수 : 0.667  부정
# 86번 노래 결과 : 긍정 : 10, 부정 : 10 , 감성 점수 : 0.5  부정
# 87번 노래 결과 : 긍정 : 12, 부정 : 0 , 감성 점수 : 0  긍정
# 88번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 89번 노래 결과 : 긍정 : 3, 부정 : 8 , 감성 점수 : 0.727  부정
# 90번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  부정
# 91번 노래 결과 : 긍정 : 13, 부정 : 5 , 감성 점수 : 0.278  긍정
# 92번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 93번 노래 결과 : 긍정 : 4, 부정 : 5 , 감성 점수 : 0.556  부정
# 94번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.308  긍정
# 95번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.615  부정
# 96번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 97번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 98번 노래 결과 : 긍정 : 7, 부정 : 1 , 감성 점수 : 0.125  긍정
# 99번 노래 결과 : 긍정 : 5, 부정 : 11 , 감성 점수 : 0.688  부정
# 100번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 101번 노래 결과 : 긍정 : 7, 부정 : 4 , 감성 점수 : 0.364  긍정
# 102번 노래 결과 : 긍정 : 6, 부정 : 11 , 감성 점수 : 0.647  부정
# 103번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 104번 노래 결과 : 긍정 : 2, 부정 : 11 , 감성 점수 : 0.846  부정
# 105번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 106번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 107번 노래 결과 : 긍정 : 11, 부정 : 7 , 감성 점수 : 0.389  긍정
# 108번 노래 결과 : 긍정 : 5, 부정 : 11 , 감성 점수 : 0.688  부정
# 109번 노래 결과 : 긍정 : 4, 부정 : 9 , 감성 점수 : 0.692  부정
# 110번 노래 결과 : 긍정 : 11, 부정 : 10 , 감성 점수 : 0.476  긍정
# 111번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 112번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 113번 노래 결과 : 긍정 : 7, 부정 : 13 , 감성 점수 : 0.65  부정
# 114번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 115번 노래 결과 : 긍정 : 7, 부정 : 11 , 감성 점수 : 0.611  부정
# 116번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 117번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 118번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 119번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 120번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  부정
# 121번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.615  부정
# 122번 노래 결과 : 긍정 : 10, 부정 : 9 , 감성 점수 : 0.474  긍정
# 123번 노래 결과 : 긍정 : 3, 부정 : 10 , 감성 점수 : 0.769  부정
# 124번 노래 결과 : 긍정 : 9, 부정 : 12 , 감성 점수 : 0.571  부정
# 125번 노래 결과 : 긍정 : 6, 부정 : 1 , 감성 점수 : 0.143  긍정
# 126번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 127번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 128번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 129번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 130번 노래 결과 : 긍정 : 4, 부정 : 9 , 감성 점수 : 0.692  부정
# 131번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 132번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.714  부정
# 133번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 134번 노래 결과 : 긍정 : 3, 부정 : 5 , 감성 점수 : 0.625  부정
# 135번 노래 결과 : 긍정 : 4, 부정 : 11 , 감성 점수 : 0.733  부정
# 136번 노래 결과 : 긍정 : 7, 부정 : 13 , 감성 점수 : 0.65  부정
# 137번 노래 결과 : 긍정 : 7, 부정 : 14 , 감성 점수 : 0.667  부정
# 138번 노래 결과 : 긍정 : 7, 부정 : 11 , 감성 점수 : 0.611  부정
# 139번 노래 결과 : 긍정 : 8, 부정 : 10 , 감성 점수 : 0.556  부정
# 140번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.583  부정
# 141번 노래 결과 : 긍정 : 12, 부정 : 5 , 감성 점수 : 0.294  긍정
# 142번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 143번 노래 결과 : 긍정 : 12, 부정 : 7 , 감성 점수 : 0.368  긍정
# 144번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 145번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 146번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 147번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.583  부정
# 148번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.455  긍정
# 149번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.333  긍정
# 150번 노래 결과 : 긍정 : 7, 부정 : 11 , 감성 점수 : 0.611  부정
# 151번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 152번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.714  부정
# 153번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.385  긍정
# 154번 노래 결과 : 긍정 : 6, 부정 : 2 , 감성 점수 : 0.25  긍정
# 155번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 156번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.714  부정
# 157번 노래 결과 : 긍정 : 5, 부정 : 4 , 감성 점수 : 0.444  긍정
# 158번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.615  부정
# 159번 노래 결과 : 긍정 : 10, 부정 : 3 , 감성 점수 : 0.231  긍정
# 160번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 161번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 162번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 163번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 164번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.545  부정
# 165번 노래 결과 : 긍정 : 1, 부정 : 4 , 감성 점수 : 0.8  부정
# 166번 노래 결과 : 긍정 : 6, 부정 : 11 , 감성 점수 : 0.647  부정
# 167번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 168번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.333  긍정
# 169번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.4  긍정
# 170번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 171번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 172번 노래 결과 : 긍정 : 6, 부정 : 11 , 감성 점수 : 0.647  부정
# 173번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.615  부정
# 174번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.636  부정
# 175번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.333  긍정
# 176번 노래 결과 : 긍정 : 5, 부정 : 3 , 감성 점수 : 0.375  긍정
# 177번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.636  부정
# 178번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.545  부정
# 179번 노래 결과 : 긍정 : 12, 부정 : 5 , 감성 점수 : 0.294  긍정
# 180번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 181번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 182번 노래 결과 : 긍정 : 3, 부정 : 4 , 감성 점수 : 0.571  부정
# 183번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 184번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 185번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 186번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.467  긍정
# 187번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 188번 노래 결과 : 긍정 : 9, 부정 : 3 , 감성 점수 : 0.25  긍정
# 189번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 190번 노래 결과 : 긍정 : 11, 부정 : 8 , 감성 점수 : 0.421  긍정
# 191번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 192번 노래 결과 : 긍정 : 4, 부정 : 6 , 감성 점수 : 0.6  부정
# 193번 노래 결과 : 긍정 : 3, 부정 : 5 , 감성 점수 : 0.625  부정
# 194번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 195번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 196번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 197번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.467  긍정
# 198번 노래 결과 : 긍정 : 9, 부정 : 11 , 감성 점수 : 0.55  부정
# 199번 노래 결과 : 긍정 : 11, 부정 : 9 , 감성 점수 : 0.45  긍정
# 200번 노래 결과 : 긍정 : 9, 부정 : 11 , 감성 점수 : 0.55  부정
# 201번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.636  부정
# 202번 노래 결과 : 긍정 : 8, 부정 : 3 , 감성 점수 : 0.273  긍정
# 203번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 204번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  부정
# 205번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.615  부정
# 206번 노래 결과 : 긍정 : 11, 부정 : 10 , 감성 점수 : 0.476  긍정
# 207번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  부정
# 208번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 209번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 210번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.4  긍정
# 211번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 212번 노래 결과 : 긍정 : 9, 부정 : 11 , 감성 점수 : 0.55  부정
# 213번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 214번 노래 결과 : 긍정 : 8, 부정 : 4 , 감성 점수 : 0.333  긍정
# 215번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 216번 노래 결과 : 긍정 : 9, 부정 : 12 , 감성 점수 : 0.571  부정
# 217번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.545  부정
# 218번 노래 결과 : 긍정 : 10, 부정 : 6 , 감성 점수 : 0.375  긍정
# 219번 노래 결과 : 긍정 : 11, 부정 : 5 , 감성 점수 : 0.312  긍정
# 220번 노래 결과 : 긍정 : 11, 부정 : 8 , 감성 점수 : 0.421  긍정
# 221번 노래 결과 : 긍정 : 4, 부정 : 6 , 감성 점수 : 0.6  부정
# 222번 노래 결과 : 긍정 : 10, 부정 : 10 , 감성 점수 : 0.5  부정
# 223번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 224번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 225번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 226번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.588  부정
# 227번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 228번 노래 결과 : 긍정 : 11, 부정 : 11 , 감성 점수 : 0.5  부정
# 229번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 230번 노래 결과 : 긍정 : 7, 부정 : 14 , 감성 점수 : 0.667  부정
# 231번 노래 결과 : 긍정 : 11, 부정 : 8 , 감성 점수 : 0.421  긍정
# 232번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 233번 노래 결과 : 긍정 : 5, 부정 : 10 , 감성 점수 : 0.667  부정
# 234번 노래 결과 : 긍정 : 6, 부정 : 11 , 감성 점수 : 0.647  부정
# 235번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 236번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  부정
# 237번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 238번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 239번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.588  부정
# 240번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.333  긍정
# 241번 노래 결과 : 긍정 : 5, 부정 : 5 , 감성 점수 : 0.5  부정
# 242번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 243번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 244번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 245번 노래 결과 : 긍정 : 9, 부정 : 14 , 감성 점수 : 0.609  부정
# 246번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 247번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.588  부정
# 248번 노래 결과 : 긍정 : 9, 부정 : 10 , 감성 점수 : 0.526  부정
# 249번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 250번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.636  부정
# 251번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 252번 노래 결과 : 긍정 : 9, 부정 : 10 , 감성 점수 : 0.526  부정
# 253번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.583  부정
# 254번 노래 결과 : 긍정 : 4, 부정 : 10 , 감성 점수 : 0.714  부정
# 255번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 256번 노래 결과 : 긍정 : 11, 부정 : 4 , 감성 점수 : 0.267  긍정
# 257번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 258번 노래 결과 : 긍정 : 3, 부정 : 10 , 감성 점수 : 0.769  부정
# 259번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  부정
# 260번 노래 결과 : 긍정 : 3, 부정 : 6 , 감성 점수 : 0.667  부정
# 261번 노래 결과 : 긍정 : 4, 부정 : 3 , 감성 점수 : 0.429  긍정
# 262번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 263번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.333  긍정
# 264번 노래 결과 : 긍정 : 4, 부정 : 5 , 감성 점수 : 0.556  부정
# 265번 노래 결과 : 긍정 : 4, 부정 : 8 , 감성 점수 : 0.667  부정
# 266번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 267번 노래 결과 : 긍정 : 10, 부정 : 9 , 감성 점수 : 0.474  긍정
# 268번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 269번 노래 결과 : 긍정 : 6, 부정 : 5 , 감성 점수 : 0.455  긍정
# 270번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.467  긍정
# 271번 노래 결과 : 긍정 : 5, 부정 : 10 , 감성 점수 : 0.667  부정
# 272번 노래 결과 : 긍정 : 9, 부정 : 9 , 감성 점수 : 0.5  부정
# 273번 노래 결과 : 긍정 : 4, 부정 : 8 , 감성 점수 : 0.667  부정
# 274번 노래 결과 : 긍정 : 10, 부정 : 7 , 감성 점수 : 0.412  긍정
# 275번 노래 결과 : 긍정 : 13, 부정 : 2 , 감성 점수 : 0.133  긍정
# 276번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.583  부정
# 277번 노래 결과 : 긍정 : 10, 부정 : 6 , 감성 점수 : 0.375  긍정
# 278번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 279번 노래 결과 : 긍정 : 5, 부정 : 11 , 감성 점수 : 0.688  부정
# 280번 노래 결과 : 긍정 : 1, 부정 : 3 , 감성 점수 : 0.75  부정
# 281번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 282번 노래 결과 : 긍정 : 7, 부정 : 3 , 감성 점수 : 0.3  긍정
# 283번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 284번 노래 결과 : 긍정 : 4, 부정 : 13 , 감성 점수 : 0.765  부정
# 285번 노래 결과 : 긍정 : 13, 부정 : 7 , 감성 점수 : 0.35  긍정
# 286번 노래 결과 : 긍정 : 6, 부정 : 10 , 감성 점수 : 0.625  부정
# 287번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.385  긍정
# 288번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 289번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 290번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 291번 노래 결과 : 긍정 : 6, 부정 : 12 , 감성 점수 : 0.667  부정
# 292번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 293번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 294번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 295번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 296번 노래 결과 : 긍정 : 12, 부정 : 6 , 감성 점수 : 0.333  긍정
# 297번 노래 결과 : 긍정 : 11, 부정 : 6 , 감성 점수 : 0.353  긍정
# 298번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 299번 노래 결과 : 긍정 : 6, 부정 : 12 , 감성 점수 : 0.667  부정
# 300번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 301번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 302번 노래 결과 : 긍정 : 3, 부정 : 6 , 감성 점수 : 0.667  부정
# 303번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.333  긍정
# 304번 노래 결과 : 긍정 : 4, 부정 : 11 , 감성 점수 : 0.733  부정
# 305번 노래 결과 : 긍정 : 11, 부정 : 9 , 감성 점수 : 0.45  긍정
# 306번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 307번 노래 결과 : 긍정 : 8, 부정 : 12 , 감성 점수 : 0.6  부정
# 308번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.438  긍정
# 309번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 310번 노래 결과 : 긍정 : 7, 부정 : 4 , 감성 점수 : 0.364  긍정
# 311번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.385  긍정
# 312번 노래 결과 : 긍정 : 3, 부정 : 13 , 감성 점수 : 0.812  부정
# 313번 노래 결과 : 긍정 : 8, 부정 : 5 , 감성 점수 : 0.385  긍정
# 314번 노래 결과 : 긍정 : 5, 부정 : 6 , 감성 점수 : 0.545  부정
# 315번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 316번 노래 결과 : 긍정 : 2, 부정 : 5 , 감성 점수 : 0.714  부정
# 317번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.333  긍정
# 318번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 319번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.588  부정
# 320번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 321번 노래 결과 : 긍정 : 9, 부정 : 3 , 감성 점수 : 0.25  긍정
# 322번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.583  부정
# 323번 노래 결과 : 긍정 : 3, 부정 : 7 , 감성 점수 : 0.7  부정
# 324번 노래 결과 : 긍정 : 7, 부정 : 9 , 감성 점수 : 0.562  부정
# 325번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 326번 노래 결과 : 긍정 : 7, 부정 : 8 , 감성 점수 : 0.533  부정
# 327번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 328번 노래 결과 : 긍정 : 10, 부정 : 5 , 감성 점수 : 0.333  긍정
# 329번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 330번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 331번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 332번 노래 결과 : 긍정 : 9, 부정 : 8 , 감성 점수 : 0.471  긍정
# 333번 노래 결과 : 긍정 : 11, 부정 : 9 , 감성 점수 : 0.45  긍정
# 334번 노래 결과 : 긍정 : 8, 부정 : 9 , 감성 점수 : 0.529  부정
# 335번 노래 결과 : 긍정 : 2, 부정 : 7 , 감성 점수 : 0.778  부정
# 336번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.615  부정
# 337번 노래 결과 : 긍정 : 3, 부정 : 10 , 감성 점수 : 0.769  부정
# 338번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.583  부정
# 339번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 340번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 341번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.636  부정
# 342번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.4  긍정
# 343번 노래 결과 : 긍정 : 7, 부정 : 12 , 감성 점수 : 0.632  부정
# 344번 노래 결과 : 긍정 : 3, 부정 : 14 , 감성 점수 : 0.824  부정
# 345번 노래 결과 : 긍정 : 5, 부정 : 9 , 감성 점수 : 0.643  부정
# 346번 노래 결과 : 긍정 : 9, 부정 : 3 , 감성 점수 : 0.25  긍정
# 347번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 348번 노래 결과 : 긍정 : 7, 부정 : 12 , 감성 점수 : 0.632  부정
# 349번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 350번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.467  긍정
# 351번 노래 결과 : 긍정 : 2, 부정 : 6 , 감성 점수 : 0.75  부정
# 352번 노래 결과 : 긍정 : 4, 부정 : 12 , 감성 점수 : 0.75  부정
# 353번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 354번 노래 결과 : 긍정 : 7, 부정 : 5 , 감성 점수 : 0.417  긍정
# 355번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 356번 노래 결과 : 긍정 : 6, 부정 : 6 , 감성 점수 : 0.5  부정
# 357번 노래 결과 : 긍정 : 9, 부정 : 4 , 감성 점수 : 0.308  긍정
# 358번 노래 결과 : 긍정 : 10, 부정 : 6 , 감성 점수 : 0.375  긍정
# 359번 노래 결과 : 긍정 : 6, 부정 : 4 , 감성 점수 : 0.4  긍정
# 360번 노래 결과 : 긍정 : 6, 부정 : 8 , 감성 점수 : 0.571  부정
# 361번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 362번 노래 결과 : 긍정 : 2, 부정 : 7 , 감성 점수 : 0.778  부정
# 363번 노래 결과 : 긍정 : 3, 부정 : 6 , 감성 점수 : 0.667  부정
# 364번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.583  부정
# 365번 노래 결과 : 긍정 : 9, 부정 : 10 , 감성 점수 : 0.526  부정
# 366번 노래 결과 : 긍정 : 4, 부정 : 7 , 감성 점수 : 0.636  부정
# 367번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.588  부정
# 368번 노래 결과 : 긍정 : 8, 부정 : 8 , 감성 점수 : 0.5  부정
# 369번 노래 결과 : 긍정 : 7, 부정 : 7 , 감성 점수 : 0.5  부정
# 370번 노래 결과 : 긍정 : 5, 부정 : 7 , 감성 점수 : 0.583  부정
# 371번 노래 결과 : 긍정 : 8, 부정 : 7 , 감성 점수 : 0.467  긍정
# 372번 노래 결과 : 긍정 : 7, 부정 : 6 , 감성 점수 : 0.462  긍정
# 373번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 374번 노래 결과 : 긍정 : 3, 부정 : 7 , 감성 점수 : 0.7  부정
# 375번 노래 결과 : 긍정 : 6, 부정 : 7 , 감성 점수 : 0.538  부정
# 376번 노래 결과 : 긍정 : 2, 부정 : 12 , 감성 점수 : 0.857  부정
# 377번 노래 결과 : 긍정 : 5, 부정 : 10 , 감성 점수 : 0.667  부정
# 378번 노래 결과 : 긍정 : 5, 부정 : 8 , 감성 점수 : 0.615  부정
# 379번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 380번 노래 결과 : 긍정 : 9, 부정 : 6 , 감성 점수 : 0.4  긍정
# 381번 노래 결과 : 긍정 : 6, 부정 : 13 , 감성 점수 : 0.684  부정
# 382번 노래 결과 : 긍정 : 6, 부정 : 9 , 감성 점수 : 0.6  부정
# 383번 노래 결과 : 긍정 : 7, 부정 : 3 , 감성 점수 : 0.3  긍정
# 384번 노래 결과 : 긍정 : 3, 부정 : 10 , 감성 점수 : 0.769  부정
# 385번 노래 결과 : 긍정 : 9, 부정 : 5 , 감성 점수 : 0.357  긍정
# 386번 노래 결과 : 긍정 : 9, 부정 : 9 , 감성 점수 : 0.5  부정
# 387번 노래 결과 : 긍정 : 8, 부정 : 6 , 감성 점수 : 0.429  긍정
# 388번 노래 결과 : 긍정 : 4, 부정 : 8 , 감성 점수 : 0.667  부정
# 389번 노래 결과 : 긍정 : 5, 부정 : 12 , 감성 점수 : 0.706  부정
# 390번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.588  부정
# 391번 노래 결과 : 긍정 : 9, 부정 : 7 , 감성 점수 : 0.438  긍정
# 392번 노래 결과 : 긍정 : 7, 부정 : 10 , 감성 점수 : 0.588  부정
# 393번 노래 결과 : 긍정 : 11, 부정 : 7 , 감성 점수 : 0.389  긍정
# 394번 노래 결과 : 긍정 : 7, 부정 : 3 , 감성 점수 : 0.3  긍정

# %%
def Total_pos(list) :
    count = 0
    for i in list:
        if(i[len(i)-2:len(i)] == '긍정'):
            count = count + 1

    return count        

sum = Total_pos(pos_result)
print('긍정 정확도: ', sum/len(Lyrics_pos))

def Total_neg(list) :
    count = 0
    for i in list:
        if(i[len(i)-2:len(i)] == '부정'):
            count = count + 1

    return count        

sum = Total_neg(pos_result)
print('부정 정확도: ', sum/len(Lyrics_pos))
# Out:
# 긍정 정확도:  0.5404624277456648
# 부정 정확도:  0.4595375722543353

# %%
# 긍정정.csv 파일 저장
import csv
with open('kosac_pos.csv', 'w', newline= '\n') as f:
  writer = csv.writer(f)
  writer.writerow(pos_result)

# %%
# 부정.csv 파일 저장
import csv
with open('kosac_neg.csv', 'w', newline= '\n') as f:
  writer = csv.writer(f)
  writer.writerow(neg_result)
